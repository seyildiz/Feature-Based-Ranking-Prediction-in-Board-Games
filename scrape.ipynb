# %%
import requests
import xml.etree.ElementTree as ET
import pandas as pd
import time
import numpy as np
from typing import Dict, List, Any
import os
from datetime import datetime

class CompleteBGGScraper:
    def __init__(self):
        self.base_url = "https://boardgamegeek.com/xmlapi2"
        self.session = requests.Session()
        self.session.headers.update({
            'User-Agent': 'BGG Complete Data Scraper 1.0'
        })
        self.max_retries = 3
        self.retry_delay = 5
    
    def get_game_details(self, game_id: int) -> Dict[str, Any]:
        """
        Fetch detailed information for a specific game ID with retry logic
        """
        url = f"{self.base_url}/thing"
        params = {
            'id': game_id,
            'stats': 1,
            'type': 'boardgame'
        }
        
        for attempt in range(self.max_retries):
            try:
                response = self.session.get(url, params=params, timeout=30)
                response.raise_for_status()
                
                root = ET.fromstring(response.content)
                item = root.find('item')
                
                if item is None:
                    return None
                
                # Extract comprehensive game data
                game_data = {
                    'id': int(item.get('id')),
                    'name': self._get_primary_name(item),
                    'year_published': self._get_year_published(item),
                    'min_players': self._get_int_value(item, 'minplayers'),
                    'max_players': self._get_int_value(item, 'maxplayers'),
                    'playing_time': self._get_int_value(item, 'playingtime'),
                    'min_play_time': self._get_int_value(item, 'minplaytime'),
                    'max_play_time': self._get_int_value(item, 'maxplaytime'),
                    'min_age': self._get_int_value(item, 'minage'),
                    'description': self._clean_description(self._get_text_value(item, 'description')),
                    'categories': self._get_linked_items(item, 'boardgamecategory'),
                    'mechanisms': self._get_linked_items(item, 'boardgamemechanic'),
                    'designers': self._get_linked_items(item, 'boardgamedesigner'),
                    'artists': self._get_linked_items(item, 'boardgameartist'),
                    'publishers': self._get_linked_items(item, 'boardgamepublisher'),
                }
                
                # Extract comprehensive statistics
                stats = item.find('statistics/ratings')
                if stats is not None:
                    game_data.update({
                        'users_rated': self._get_int_value(stats, 'usersrated'),
                        'average_rating': self._get_float_value(stats, 'average'),
                        'bayes_average': self._get_float_value(stats, 'bayesaverage'),
                        'num_comments': self._get_int_value(stats, 'numcomments'),
                        'num_weights': self._get_int_value(stats, 'numweights'),
                        'average_weight': self._get_float_value(stats, 'averageweight'),
                        'bgg_rank': self._get_bgg_rank(stats),
                        'category_ranks': self._get_category_ranks(stats),
                    })
                
                return game_data
                
            except (requests.RequestException, ET.ParseError) as e:
                print(f"Attempt {attempt + 1} failed for game {game_id}: {e}")
                if attempt < self.max_retries - 1:
                    time.sleep(self.retry_delay)
                else:
                    print(f"Failed to fetch game {game_id} after {self.max_retries} attempts")
                    return None
    
    def get_game_ids_by_year_range(self, start_year=1950, end_year=2024):
        """
        Get game IDs by searching year ranges (more comprehensive approach)
        """
        all_game_ids = set()
        
        print(f"Searching for games from {start_year} to {end_year}...")
        
        # Search by year ranges to get comprehensive coverage
        for year in range(start_year, end_year + 1):
            print(f"Searching games from {year}...")
            year_ids = self._search_games_by_year(year)
            all_game_ids.update(year_ids)
            time.sleep(2)  # Rate limiting
        
        return list(all_game_ids)
    
    def _search_games_by_year(self, year):
        """Search games by specific year using BGG search"""
        url = f"{self.base_url}/search"
        params = {
            'query': f'',
            'type': 'boardgame',
            'yearpublished': year
        }
        
        try:
            response = self.session.get(url, params=params)
            response.raise_for_status()
            
            root = ET.fromstring(response.content)
            game_ids = []
            
            for item in root.findall('item'):
                game_ids.append(int(item.get('id')))
            
            print(f"Found {len(game_ids)} games for year {year}")
            return game_ids
            
        except Exception as e:
            print(f"Error searching games for year {year}: {e}")
            return []
    
    def get_all_ranked_games(self):
        """
        Get all games that have rankings (comprehensive but more focused dataset)
        """
        print("This method will take a very long time and may not be complete.")
        print("BGG doesn't provide a direct way to get ALL games.")
        print("Consider using ID ranges or specific collections instead.")
        
        # You can try sequential ID approach (not recommended for all games)
        return self.get_games_by_id_range(1, 50000)  # Adjust range as needed
    
    def get_games_by_id_range(self, start_id=1, end_id=1000):
        """
        Get games by ID range - useful for comprehensive scraping
        """
        print(f"Getting games from ID {start_id} to {end_id}")
        return list(range(start_id, end_id + 1))
    
    def get_games_from_collections(self):
        """
        Get games from various BGG collections and rankings
        """
        collections = {
            'hot': self._get_hot_games(),
            'top_rated': self._get_top_rated_games(),
            # Add more collection methods as needed
        }
        
        all_ids = set()
        for collection_name, ids in collections.items():
            print(f"Found {len(ids)} games in {collection_name}")
            all_ids.update(ids)
        
        return list(all_ids)
    
    def _get_hot_games(self):
        """Get current hot games"""
        url = f"{self.base_url}/hot"
        params = {'type': 'boardgame'}
        
        try:
            response = self.session.get(url, params=params)
            response.raise_for_status()
            root = ET.fromstring(response.content)
            return [int(item.get('id')) for item in root.findall('item')]
        except:
            return []
    
    def _get_top_rated_games(self):
        """Get top rated games - you'd need to implement BGG browse functionality"""
        # This is a placeholder - BGG's browse functionality is complex
        # You might need to scrape the web interface or use other methods
        return []
    
    def scrape_games_batch(self, game_ids: List[int], batch_size=50, delay=1.0, 
                          save_progress=True, output_dir='bgg_data', 
                          null_check_mode="important") -> pd.DataFrame:
        """
        Scrape games in batches with progress saving and comprehensive null checking
        
        Args:
            game_ids: List of BGG game IDs to scrape
            batch_size: Number of games to process per batch
            delay: Delay between API requests in seconds
            save_progress: Whether to save progress after each batch
            output_dir: Directory to save progress files
            null_check_mode: Level of null checking
                - "critical": Only check essential fields (name, year, id)
                - "important": Check critical + important fields (players, rating, etc.)
                - "all": Check all fields - strictest filtering
        """
        if save_progress:
            os.makedirs(output_dir, exist_ok=True)
        
        all_games_data = []
        total_games = len(game_ids)
        
        print(f"Starting to scrape {total_games} games in batches of {batch_size}...")
        
        for batch_start in range(0, total_games, batch_size):
            batch_end = min(batch_start + batch_size, total_games)
            batch_ids = game_ids[batch_start:batch_end]
            
            print(f"\nProcessing batch {batch_start//batch_size + 1}: games {batch_start+1}-{batch_end}")
            
            batch_data = []
            for i, game_id in enumerate(batch_ids):
                print(f"  Scraping game {batch_start + i + 1}/{total_games}: ID {game_id}")
                
                game_data = self.get_game_details(game_id)
                
                if game_data and self._is_valid_game(game_data, null_check_mode):
                    batch_data.append(game_data)
                    print(f"    ✓ Valid game added: {game_data.get('name', 'Unknown')}")
                else:
                    print(f"    ✗ Skipping game {game_id} - failed validation")
                
                time.sleep(delay)
            
            all_games_data.extend(batch_data)
            
            # Save progress after each batch
            if save_progress and batch_data:
                batch_df = pd.DataFrame(batch_data)
                timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
                batch_file = f"{output_dir}/batch_{batch_start//batch_size + 1}_{timestamp}.csv"
                batch_df.to_csv(batch_file, index=False, encoding='utf-8')
                print(f"  Saved batch to {batch_file}")
        
        print(f"\nCompleted scraping. Total valid games: {len(all_games_data)}")
        
        # Create final DataFrame
        if all_games_data:
            df = pd.DataFrame(all_games_data)
            df = self._clean_dataframe(df)
            
            # Save final dataset
            if save_progress:
                final_file = f"{output_dir}/complete_bgg_dataset_{datetime.now().strftime('%Y%m%d_%H%M%S')}.csv"
                df.to_csv(final_file, index=False, encoding='utf-8')
                print(f"Final dataset saved to {final_file}")
            
            return df
        else:
            return pd.DataFrame()
    
    def _is_valid_game(self, game_data, strict_mode=True):
        """
        Check if game data meets quality criteria with configurable null checking
        
        Args:
            game_data: Dictionary containing game data
            strict_mode: If True, checks all fields. If False, only checks critical fields.
        """
        if not game_data:
            return False
        
        # Critical fields that must never be null
        critical_fields = [
            'name', 
            'year_published', 
            'id'
        ]
        
        # Important fields that should preferably not be null
        important_fields = [
            'min_players',
            'max_players', 
            'playing_time',
            'min_age',
            'average_rating',
            'users_rated'
        ]
        
        # All possible fields for strictest checking
        all_fields = critical_fields + important_fields + [
            'min_play_time',
            'max_play_time', 
            'description',
            'categories',
            'mechanisms',
            'designers',
            'artists', 
            'publishers',
            'bayes_average',
            'num_comments',
            'num_weights',
            'average_weight',
            'bgg_rank',
            'category_ranks'
        ]
        
        if strict_mode == "critical":
            # Only check critical fields
            fields_to_check = critical_fields
        elif strict_mode == "important":
            # Check critical + important fields
            fields_to_check = critical_fields + important_fields
        elif strict_mode == "all" or strict_mode is True:
            # Check all fields
            fields_to_check = all_fields
        else:
            # Default to critical fields
            fields_to_check = critical_fields
        
        # Check for null/empty values
        for field in fields_to_check:
            value = game_data.get(field)
            if value is None or value == '' or value == 'None':
                print(f"    Rejecting game {game_data.get('id', 'Unknown')} - null/empty field: {field}")
                return False
        
        # Additional validation checks
        year = game_data.get('year_published')
        if year and (year < 1800 or year > 2030):
            print(f"    Rejecting game {game_data.get('id', 'Unknown')} - invalid year: {year}")
            return False
            
        min_players = game_data.get('min_players')
        max_players = game_data.get('max_players')
        if min_players and max_players and min_players > max_players:
            print(f"    Rejecting game {game_data.get('id', 'Unknown')} - min_players > max_players")
            return False
        
        rating = game_data.get('average_rating')
        if rating and (rating < 0 or rating > 10):
            print(f"    Rejecting game {game_data.get('id', 'Unknown')} - invalid rating: {rating}")
            return False
        
        return True
    
    def _clean_dataframe(self, df, final_null_check=True):
        """
        Clean the final dataframe with additional null checking
        
        Args:
            df: DataFrame to clean
            final_null_check: Whether to do a final comprehensive null check
        """
        print(f"Cleaning dataframe - initial size: {len(df)} games")
        
        # Remove rows with null critical values
        critical_cols = ['name', 'year_published', 'id']
        initial_size = len(df)
        df = df.dropna(subset=critical_cols)
        print(f"After critical field null check: {len(df)} games ({initial_size - len(df)} removed)")
        
        # Remove duplicates
        initial_size = len(df)
        df = df.drop_duplicates(subset=['id'])
        print(f"After duplicate removal: {len(df)} games ({initial_size - len(df)} removed)")
        
        if final_null_check:
            # Calculate null percentage for each row
            null_threshold = 0.5  # Remove rows with more than 50% null values
            initial_size = len(df)
            
            null_counts = df.isnull().sum(axis=1)
            total_cols = len(df.columns)
            null_percentages = null_counts / total_cols
            
            df = df[null_percentages <= null_threshold]
            print(f"After removing rows with >{null_threshold*100}% nulls: {len(df)} games ({initial_size - len(df)} removed)")
        
        # Sort by BGG rank (nulls last)
        df = df.sort_values('bgg_rank', na_position='last')
        
        # Print final null statistics
        print(f"\nFinal dataset null statistics:")
        null_stats = df.isnull().sum()
        for col, null_count in null_stats.items():
            if null_count > 0:
                percentage = (null_count / len(df)) * 100
                print(f"  {col}: {null_count} nulls ({percentage:.1f}%)")
        
        return df
    
    def _clean_description(self, description):
        """Clean HTML from description"""
        if description:
            # Basic HTML tag removal
            import re
            clean_desc = re.sub(r'<[^>]+>', '', description)
            return clean_desc.strip()
        return description
    
    def _get_primary_name(self, item):
        """Get the primary name of the game"""
        names = item.findall('name')
        for name in names:
            if name.get('type') == 'primary':
                return name.get('value')
        return names[0].get('value') if names else None
    
    def _get_alternative_names(self, item):
        """Get alternative names"""
        names = item.findall('name')
        alt_names = [name.get('value') for name in names if name.get('type') == 'alternate']
        return ', '.join(alt_names) if alt_names else None
    
    def _get_year_published(self, item):
        """Get year published"""
        year_elem = item.find('yearpublished')
        return int(year_elem.get('value')) if year_elem is not None else None
    
    def _get_int_value(self, parent, tag):
        """Get integer value from XML element"""
        elem = parent.find(tag)
        if elem is not None:
            value = elem.get('value')
            try:
                return int(value) if value else None
            except ValueError:
                return None
        return None
    
    def _get_float_value(self, parent, tag):
        """Get float value from XML element"""
        elem = parent.find(tag)
        if elem is not None:
            value = elem.get('value')
            try:
                return float(value) if value else None
            except ValueError:
                return None
        return None
    
    def _get_text_value(self, parent, tag):
        """Get text value from XML element"""
        elem = parent.find(tag)
        return elem.text if elem is not None else None
    
    def _get_linked_items(self, parent, link_type):
        """Get linked items as comma-separated string"""
        links = parent.findall(f'link[@type="{link_type}"]')
        if links:
            return ', '.join([link.get('value') for link in links])
        return None
    
    def _get_bgg_rank(self, stats):
        """Get BGG overall rank"""
        ranks = stats.findall('ranks/rank')
        for rank in ranks:
            if rank.get('name') == 'boardgame':
                rank_value = rank.get('value')
                if rank_value and rank_value.isdigit():
                    return int(rank_value)
        return None
    
    def _get_category_ranks(self, stats):
        """Get category-specific ranks"""
        ranks = stats.findall('ranks/rank')
        category_ranks = {}
        for rank in ranks:
            name = rank.get('name')
            if name and name != 'boardgame':
                rank_value = rank.get('value')
                if rank_value and rank_value.isdigit():
                    category_ranks[name] = int(rank_value)
        return str(category_ranks) if category_ranks else None

# Different scraping strategies
def scrape_comprehensive_dataset():
    """
    Main function with multiple strategies for comprehensive scraping
    """
    scraper = CompleteBGGScraper()
    
    print("=== BGG Comprehensive Data Scraper ===")
    print("\nChoose your scraping strategy:")
    print("1. ID Range (recommended for testing): Scrape games by ID range")
    print("2. Year Range: Scrape games by publication years")
    print("3. Collections: Scrape from various BGG collections")
    print("4. Custom list: Provide your own game IDs")
    
    #strategy = input("\nEnter strategy number (1-4): ").strip()
    strategy = "5"
    
    if strategy == "1":
        start_id = int(input("Enter start ID (e.g., 1): "))
        end_id = int(input("Enter end ID (e.g., 10000): "))
        game_ids = scraper.get_games_by_id_range(start_id, end_id)
        
    elif strategy == "2":
        start_year = int(input("Enter start year (e.g., 2000): "))
        end_year = int(input("Enter end year (e.g., 2024): "))
        game_ids = scraper.get_game_ids_by_year_range(start_year, end_year)
        
    elif strategy == "3":
        game_ids = scraper.get_games_from_collections()
        
    elif strategy == "4":
        ids_input = input("Enter game IDs separated by commas: ")
        game_ids = [int(x.strip()) for x in ids_input.split(',')]
        
    else:
        print("Invalid choice. Using default ID range 1-1000")
        game_ids = scraper.get_games_by_id_range(408950, 415000)
    
    if not game_ids:
        print("No game IDs found. Exiting.")
        return
    
    print(f"\nFound {len(game_ids)} games to scrape")
    
    # Null checking options
    print("\nNull checking strictness:")
    print("1. Critical only: name, year_published, id")
    print("2. Important: critical + players, rating, etc.")
    print("3. All fields: strictest filtering (recommended)")
    
    null_check = input("Enter null check level (1-3, default=2): ").strip()
    null_modes = {"1": "critical", "2": "important", "3": "all"}
    null_check_mode = null_modes.get(null_check, "important")
    
    # Scraping parameters
    batch_size = int(input("Enter batch size (recommended: 50-100): ") or "50")
    delay = float(input("Enter delay between requests in seconds (recommended: 1.0-2.0): ") or "1.0")
    
    # Start scraping
    df = scraper.scrape_games_batch(
        game_ids=game_ids,
        batch_size=batch_size,
        delay=delay,
        save_progress=True,
        null_check_mode=null_check_mode
    )
    
    if not df.empty:
        print(f"\n=== SCRAPING COMPLETE ===")
        print(f"Total games scraped: {len(df)}")
        print(f"Columns: {len(df.columns)}")
        print(f"Date range: {df['year_published'].min()} - {df['year_published'].max()}")
        print(f"Average rating range: {df['average_rating'].min():.2f} - {df['average_rating'].max():.2f}")
        
        # Show sample
        print(f"\nSample data:")
        print(df[['name', 'year_published', 'average_rating', 'bgg_rank']].head(10))
        
    else:
        print("No data was scraped successfully.")

# Quick start functions for specific use cases
def scrape_top_games(num_games=1000, null_check_mode="important"):
    """Quick function to scrape top games with null checking"""
    scraper = CompleteBGGScraper()
    game_ids = scraper.get_games_by_id_range(1, num_games)
    return scraper.scrape_games_batch(game_ids, batch_size=50, delay=1.0, null_check_mode=null_check_mode)

def scrape_recent_games(start_year=2020, null_check_mode="important"):
    """Quick function to scrape recent games with null checking"""
    scraper = CompleteBGGScraper()
    game_ids = scraper.get_game_ids_by_year_range(start_year, 2025)
    return scraper.scrape_games_batch(game_ids, batch_size=100, delay=1.0, null_check_mode=null_check_mode)

def scrape_clean_dataset(game_ids, null_check_mode="all"):
    """
    Scrape with strictest null checking for cleanest dataset
    
    Args:
        game_ids: List of game IDs to scrape
        null_check_mode: "critical", "important", or "all"
    """
    scraper = CompleteBGGScraper()
    print(f"Scraping {len(game_ids)} games with '{null_check_mode}' null checking...")
    return scraper.scrape_games_batch(
        game_ids, 
        batch_size=50, 
        delay=1.5, 
        null_check_mode=null_check_mode
    )

if __name__ == "__main__":
    scrape_comprehensive_dataset()
# Out:
# === BGG Comprehensive Data Scraper ===
#
# Choose your scraping strategy:
# 1. ID Range (recommended for testing): Scrape games by ID range
# 2. Year Range: Scrape games by publication years
# 3. Collections: Scrape from various BGG collections
# 4. Custom list: Provide your own game IDs
# Invalid choice. Using default ID range 1-1000
# Getting games from ID 408950 to 415000
#
# Found 6051 games to scrape
#
# Null checking strictness:
# 1. Critical only: name, year_published, id
# 2. Important: critical + players, rating, etc.
# 3. All fields: strictest filtering (recommended)
# Starting to scrape 6051 games in batches of 100...
#
# Processing batch 1: games 1-100
#   Scraping game 1/6051: ID 408950
#     ✗ Skipping game 408950 - failed validation
#   Scraping game 2/6051: ID 408951
#     ✗ Skipping game 408951 - failed validation
#   Scraping game 3/6051: ID 408952
#     ✗ Skipping game 408952 - failed validation
#   Scraping game 4/6051: ID 408953
#     ✗ Skipping game 408953 - failed validation
#   Scraping game 5/6051: ID 408954
#     ✗ Skipping game 408954 - failed validation
#   Scraping game 6/6051: ID 408955
#     ✗ Skipping game 408955 - failed validation
#   Scraping game 7/6051: ID 408956
#     ✗ Skipping game 408956 - failed validation
#   Scraping game 8/6051: ID 408957
#     ✗ Skipping game 408957 - failed validation
#   Scraping game 9/6051: ID 408958
#     ✗ Skipping game 408958 - failed validation
#   Scraping game 10/6051: ID 408959
#     ✗ Skipping game 408959 - failed validation
#   Scraping game 11/6051: ID 408960
#     ✗ Skipping game 408960 - failed validation
#   Scraping game 12/6051: ID 408961
#     ✗ Skipping game 408961 - failed validation
#   Scraping game 13/6051: ID 408962
#     ✗ Skipping game 408962 - failed validation
#   Scraping game 14/6051: ID 408963
#     ✗ Skipping game 408963 - failed validation
#   Scraping game 15/6051: ID 408964
#     ✗ Skipping game 408964 - failed validation
#   Scraping game 16/6051: ID 408965
#     ✗ Skipping game 408965 - failed validation
#   Scraping game 17/6051: ID 408966
#     ✗ Skipping game 408966 - failed validation
#   Scraping game 18/6051: ID 408967
#     ✗ Skipping game 408967 - failed validation
#   Scraping game 19/6051: ID 408968
#     ✗ Skipping game 408968 - failed validation
#   Scraping game 20/6051: ID 408969
#     ✗ Skipping game 408969 - failed validation
#   Scraping game 21/6051: ID 408970
#     ✗ Skipping game 408970 - failed validation
#   Scraping game 22/6051: ID 408971
#     ✗ Skipping game 408971 - failed validation
#   Scraping game 23/6051: ID 408972
#     ✗ Skipping game 408972 - failed validation
#   Scraping game 24/6051: ID 408973
#     Rejecting game 408973 - null/empty field: designers
#     ✗ Skipping game 408973 - failed validation
#   Scraping game 25/6051: ID 408974
#     ✗ Skipping game 408974 - failed validation
#   Scraping game 26/6051: ID 408975
#     ✗ Skipping game 408975 - failed validation
#   Scraping game 27/6051: ID 408976
#     ✗ Skipping game 408976 - failed validation
#   Scraping game 28/6051: ID 408977
#     ✗ Skipping game 408977 - failed validation
#   Scraping game 29/6051: ID 408978
#     ✗ Skipping game 408978 - failed validation
#   Scraping game 30/6051: ID 408979
#     ✗ Skipping game 408979 - failed validation
#   Scraping game 31/6051: ID 408980
#     ✗ Skipping game 408980 - failed validation
#   Scraping game 32/6051: ID 408981
#     ✗ Skipping game 408981 - failed validation
#   Scraping game 33/6051: ID 408982
#     ✗ Skipping game 408982 - failed validation
#   Scraping game 34/6051: ID 408983
#     ✗ Skipping game 408983 - failed validation
#   Scraping game 35/6051: ID 408984
#     ✗ Skipping game 408984 - failed validation
#   Scraping game 36/6051: ID 408985
#     ✗ Skipping game 408985 - failed validation
#   Scraping game 37/6051: ID 408986
#     ✗ Skipping game 408986 - failed validation
#   Scraping game 38/6051: ID 408987
#     ✗ Skipping game 408987 - failed validation
#   Scraping game 39/6051: ID 408988
#     Rejecting game 408988 - null/empty field: artists
#     ✗ Skipping game 408988 - failed validation
#   Scraping game 40/6051: ID 408989
#     ✗ Skipping game 408989 - failed validation
#   Scraping game 41/6051: ID 408990
#     ✗ Skipping game 408990 - failed validation
#   Scraping game 42/6051: ID 408991
#     Rejecting game 408991 - null/empty field: designers
#     ✗ Skipping game 408991 - failed validation
#   Scraping game 43/6051: ID 408992
#     Rejecting game 408992 - null/empty field: designers
#     ✗ Skipping game 408992 - failed validation
#   Scraping game 44/6051: ID 408993
#     ✗ Skipping game 408993 - failed validation
#   Scraping game 45/6051: ID 408994
#     ✗ Skipping game 408994 - failed validation
#   Scraping game 46/6051: ID 408995
#     Rejecting game 408995 - null/empty field: designers
#     ✗ Skipping game 408995 - failed validation
#   Scraping game 47/6051: ID 408996
#     ✗ Skipping game 408996 - failed validation
#   Scraping game 48/6051: ID 408997
#     ✗ Skipping game 408997 - failed validation
#   Scraping game 49/6051: ID 408998
#     ✗ Skipping game 408998 - failed validation
#   Scraping game 50/6051: ID 408999
#     ✗ Skipping game 408999 - failed validation
#   Scraping game 51/6051: ID 409000
#     ✗ Skipping game 409000 - failed validation
#   Scraping game 52/6051: ID 409001
#     ✗ Skipping game 409001 - failed validation
#   Scraping game 53/6051: ID 409002
#     ✗ Skipping game 409002 - failed validation
#   Scraping game 54/6051: ID 409003
#     ✗ Skipping game 409003 - failed validation
#   Scraping game 55/6051: ID 409004
#     ✗ Skipping game 409004 - failed validation
#   Scraping game 56/6051: ID 409005
#     Rejecting game 409005 - null/empty field: category_ranks
#     ✗ Skipping game 409005 - failed validation
#   Scraping game 57/6051: ID 409006
#     ✗ Skipping game 409006 - failed validation
#   Scraping game 58/6051: ID 409007
#     ✗ Skipping game 409007 - failed validation
#   Scraping game 59/6051: ID 409008
#     ✗ Skipping game 409008 - failed validation
#   Scraping game 60/6051: ID 409009
#     Rejecting game 409009 - null/empty field: designers
#     ✗ Skipping game 409009 - failed validation
#   Scraping game 61/6051: ID 409010
#     Rejecting game 409010 - null/empty field: artists
#     ✗ Skipping game 409010 - failed validation
#   Scraping game 62/6051: ID 409011
#     ✗ Skipping game 409011 - failed validation
#   Scraping game 63/6051: ID 409012
#     ✗ Skipping game 409012 - failed validation
#   Scraping game 64/6051: ID 409013
#     ✗ Skipping game 409013 - failed validation
#   Scraping game 65/6051: ID 409014
#     ✗ Skipping game 409014 - failed validation
#   Scraping game 66/6051: ID 409015
#     Rejecting game 409015 - null/empty field: artists
#     ✗ Skipping game 409015 - failed validation
#   Scraping game 67/6051: ID 409016
#     ✗ Skipping game 409016 - failed validation
#   Scraping game 68/6051: ID 409017
#     ✗ Skipping game 409017 - failed validation
#   Scraping game 69/6051: ID 409018
#     ✗ Skipping game 409018 - failed validation
#   Scraping game 70/6051: ID 409019
#     ✗ Skipping game 409019 - failed validation
#   Scraping game 71/6051: ID 409020
#     ✗ Skipping game 409020 - failed validation
#   Scraping game 72/6051: ID 409021
#     Rejecting game 409021 - null/empty field: bgg_rank
#     ✗ Skipping game 409021 - failed validation
#   Scraping game 73/6051: ID 409022
#     ✗ Skipping game 409022 - failed validation
#   Scraping game 74/6051: ID 409023
#     ✗ Skipping game 409023 - failed validation
#   Scraping game 75/6051: ID 409024
#     ✗ Skipping game 409024 - failed validation
#   Scraping game 76/6051: ID 409025
#     ✗ Skipping game 409025 - failed validation
#   Scraping game 77/6051: ID 409026
#     ✗ Skipping game 409026 - failed validation
#   Scraping game 78/6051: ID 409027
#     ✗ Skipping game 409027 - failed validation
#   Scraping game 79/6051: ID 409028
#     ✗ Skipping game 409028 - failed validation
#   Scraping game 80/6051: ID 409029
#     ✗ Skipping game 409029 - failed validation
#   Scraping game 81/6051: ID 409030
#     ✗ Skipping game 409030 - failed validation
#   Scraping game 82/6051: ID 409031
#     Rejecting game 409031 - null/empty field: category_ranks
#     ✗ Skipping game 409031 - failed validation
#   Scraping game 83/6051: ID 409032
#     ✗ Skipping game 409032 - failed validation
#   Scraping game 84/6051: ID 409033
#     ✗ Skipping game 409033 - failed validation
#   Scraping game 85/6051: ID 409034
#     ✗ Skipping game 409034 - failed validation
#   Scraping game 86/6051: ID 409035
#     ✗ Skipping game 409035 - failed validation
#   Scraping game 87/6051: ID 409036
#     ✗ Skipping game 409036 - failed validation
#   Scraping game 88/6051: ID 409037
#     ✗ Skipping game 409037 - failed validation
#   Scraping game 89/6051: ID 409038
#     ✗ Skipping game 409038 - failed validation
#   Scraping game 90/6051: ID 409039
#     ✗ Skipping game 409039 - failed validation
#   Scraping game 91/6051: ID 409040
#     ✗ Skipping game 409040 - failed validation
#   Scraping game 92/6051: ID 409041
#     ✗ Skipping game 409041 - failed validation
#   Scraping game 93/6051: ID 409042
#     ✗ Skipping game 409042 - failed validation
#   Scraping game 94/6051: ID 409043
#     ✗ Skipping game 409043 - failed validation
#   Scraping game 95/6051: ID 409044
#     Rejecting game 409044 - null/empty field: categories
#     ✗ Skipping game 409044 - failed validation
#   Scraping game 96/6051: ID 409045
#     ✗ Skipping game 409045 - failed validation
#   Scraping game 97/6051: ID 409046
#     ✗ Skipping game 409046 - failed validation
#   Scraping game 98/6051: ID 409047
#     Rejecting game 409047 - null/empty field: bgg_rank
#     ✗ Skipping game 409047 - failed validation
#   Scraping game 99/6051: ID 409048
#     Rejecting game 409048 - null/empty field: bgg_rank
#     ✗ Skipping game 409048 - failed validation
#   Scraping game 100/6051: ID 409049
#     Rejecting game 409049 - null/empty field: designers
#     ✗ Skipping game 409049 - failed validation
#
# Processing batch 2: games 101-200
#   Scraping game 101/6051: ID 409050
#     ✗ Skipping game 409050 - failed validation
#   Scraping game 102/6051: ID 409051
#     Rejecting game 409051 - null/empty field: designers
#     ✗ Skipping game 409051 - failed validation
#   Scraping game 103/6051: ID 409052
#     Rejecting game 409052 - null/empty field: bgg_rank
#     ✗ Skipping game 409052 - failed validation
#   Scraping game 104/6051: ID 409053
#     ✗ Skipping game 409053 - failed validation
#   Scraping game 105/6051: ID 409054
#     ✗ Skipping game 409054 - failed validation
#   Scraping game 106/6051: ID 409055
#     ✗ Skipping game 409055 - failed validation
#   Scraping game 107/6051: ID 409056
#     ✗ Skipping game 409056 - failed validation
#   Scraping game 108/6051: ID 409057
#     ✗ Skipping game 409057 - failed validation
#   Scraping game 109/6051: ID 409058
#     ✗ Skipping game 409058 - failed validation
#   Scraping game 110/6051: ID 409059
#     ✗ Skipping game 409059 - failed validation
#   Scraping game 111/6051: ID 409060
#     ✗ Skipping game 409060 - failed validation
#   Scraping game 112/6051: ID 409061
#     ✗ Skipping game 409061 - failed validation
#   Scraping game 113/6051: ID 409062
#     ✗ Skipping game 409062 - failed validation
#   Scraping game 114/6051: ID 409063
#     ✗ Skipping game 409063 - failed validation
#   Scraping game 115/6051: ID 409064
#     ✗ Skipping game 409064 - failed validation
#   Scraping game 116/6051: ID 409065
#     ✗ Skipping game 409065 - failed validation
#   Scraping game 117/6051: ID 409066
#     ✗ Skipping game 409066 - failed validation
#   Scraping game 118/6051: ID 409067
#     Rejecting game 409067 - null/empty field: artists
#     ✗ Skipping game 409067 - failed validation
#   Scraping game 119/6051: ID 409068
#     Rejecting game 409068 - null/empty field: categories
#     ✗ Skipping game 409068 - failed validation
#   Scraping game 120/6051: ID 409069
#     Rejecting game 409069 - null/empty field: designers
#     ✗ Skipping game 409069 - failed validation
#   Scraping game 121/6051: ID 409070
#     ✗ Skipping game 409070 - failed validation
#   Scraping game 122/6051: ID 409071
#     ✗ Skipping game 409071 - failed validation
#   Scraping game 123/6051: ID 409072
#     ✗ Skipping game 409072 - failed validation
#   Scraping game 124/6051: ID 409073
#     ✗ Skipping game 409073 - failed validation
#   Scraping game 125/6051: ID 409074
#     ✗ Skipping game 409074 - failed validation
#   Scraping game 126/6051: ID 409075
#     ✗ Skipping game 409075 - failed validation
#   Scraping game 127/6051: ID 409076
#     ✗ Skipping game 409076 - failed validation
#   Scraping game 128/6051: ID 409077
#     ✗ Skipping game 409077 - failed validation
#   Scraping game 129/6051: ID 409078
#     ✗ Skipping game 409078 - failed validation
#   Scraping game 130/6051: ID 409079
#     Rejecting game 409079 - null/empty field: bgg_rank
#     ✗ Skipping game 409079 - failed validation
#   Scraping game 131/6051: ID 409080
#     ✗ Skipping game 409080 - failed validation
#   Scraping game 132/6051: ID 409081
#     ✗ Skipping game 409081 - failed validation
#   Scraping game 133/6051: ID 409082
#     ✗ Skipping game 409082 - failed validation
#   Scraping game 134/6051: ID 409083
#     ✗ Skipping game 409083 - failed validation
#   Scraping game 135/6051: ID 409084
#     ✗ Skipping game 409084 - failed validation
#   Scraping game 136/6051: ID 409085
#     ✗ Skipping game 409085 - failed validation
#   Scraping game 137/6051: ID 409086
#     ✗ Skipping game 409086 - failed validation
#   Scraping game 138/6051: ID 409087
#     ✗ Skipping game 409087 - failed validation
#   Scraping game 139/6051: ID 409088
#     ✗ Skipping game 409088 - failed validation
#   Scraping game 140/6051: ID 409089
#     Rejecting game 409089 - null/empty field: bgg_rank
#     ✗ Skipping game 409089 - failed validation
#   Scraping game 141/6051: ID 409090
#     ✗ Skipping game 409090 - failed validation
#   Scraping game 142/6051: ID 409091
#     ✗ Skipping game 409091 - failed validation
#   Scraping game 143/6051: ID 409092
#     ✗ Skipping game 409092 - failed validation
#   Scraping game 144/6051: ID 409093
#     ✗ Skipping game 409093 - failed validation
#   Scraping game 145/6051: ID 409094
#     ✗ Skipping game 409094 - failed validation
#   Scraping game 146/6051: ID 409095
#     ✗ Skipping game 409095 - failed validation
#   Scraping game 147/6051: ID 409096
#     ✗ Skipping game 409096 - failed validation
#   Scraping game 148/6051: ID 409097
#     ✗ Skipping game 409097 - failed validation
#   Scraping game 149/6051: ID 409098
#     ✗ Skipping game 409098 - failed validation
#   Scraping game 150/6051: ID 409099
#     ✗ Skipping game 409099 - failed validation
#   Scraping game 151/6051: ID 409100
#     ✗ Skipping game 409100 - failed validation
#   Scraping game 152/6051: ID 409101
#     ✗ Skipping game 409101 - failed validation
#   Scraping game 153/6051: ID 409102
#     ✗ Skipping game 409102 - failed validation
#   Scraping game 154/6051: ID 409103
#     ✗ Skipping game 409103 - failed validation
#   Scraping game 155/6051: ID 409104
#     Rejecting game 409104 - null/empty field: artists
#     ✗ Skipping game 409104 - failed validation
#   Scraping game 156/6051: ID 409105
#     Rejecting game 409105 - null/empty field: artists
#     ✗ Skipping game 409105 - failed validation
#   Scraping game 157/6051: ID 409106
#     ✗ Skipping game 409106 - failed validation
#   Scraping game 158/6051: ID 409107
#     ✗ Skipping game 409107 - failed validation
#   Scraping game 159/6051: ID 409108
#     ✗ Skipping game 409108 - failed validation
#   Scraping game 160/6051: ID 409109
#     ✗ Skipping game 409109 - failed validation
#   Scraping game 161/6051: ID 409110
#     Rejecting game 409110 - null/empty field: artists
#     ✗ Skipping game 409110 - failed validation
#   Scraping game 162/6051: ID 409111
#     ✗ Skipping game 409111 - failed validation
#   Scraping game 163/6051: ID 409112
#     ✗ Skipping game 409112 - failed validation
#   Scraping game 164/6051: ID 409113
#     ✗ Skipping game 409113 - failed validation
#   Scraping game 165/6051: ID 409114
#     ✗ Skipping game 409114 - failed validation
#   Scraping game 166/6051: ID 409115
#     ✗ Skipping game 409115 - failed validation
#   Scraping game 167/6051: ID 409116
#     Rejecting game 409116 - null/empty field: mechanisms
#     ✗ Skipping game 409116 - failed validation
#   Scraping game 168/6051: ID 409117
#     ✗ Skipping game 409117 - failed validation
#   Scraping game 169/6051: ID 409118
#     ✗ Skipping game 409118 - failed validation
#   Scraping game 170/6051: ID 409119
#     Rejecting game 409119 - null/empty field: designers
#     ✗ Skipping game 409119 - failed validation
#   Scraping game 171/6051: ID 409120
#     ✗ Skipping game 409120 - failed validation
#   Scraping game 172/6051: ID 409121
#     Rejecting game 409121 - null/empty field: artists
#     ✗ Skipping game 409121 - failed validation
#   Scraping game 173/6051: ID 409122
#     ✗ Skipping game 409122 - failed validation
#   Scraping game 174/6051: ID 409123
#     ✗ Skipping game 409123 - failed validation
#   Scraping game 175/6051: ID 409124
#     ✗ Skipping game 409124 - failed validation
#   Scraping game 176/6051: ID 409125
#     ✗ Skipping game 409125 - failed validation
#   Scraping game 177/6051: ID 409126
#     ✗ Skipping game 409126 - failed validation
#   Scraping game 178/6051: ID 409127
#     ✗ Skipping game 409127 - failed validation
#   Scraping game 179/6051: ID 409128
#     ✗ Skipping game 409128 - failed validation
#   Scraping game 180/6051: ID 409129
#     ✗ Skipping game 409129 - failed validation
#   Scraping game 181/6051: ID 409130
#     ✗ Skipping game 409130 - failed validation
#   Scraping game 182/6051: ID 409131
#     ✗ Skipping game 409131 - failed validation
#   Scraping game 183/6051: ID 409132
#     ✗ Skipping game 409132 - failed validation
#   Scraping game 184/6051: ID 409133
#     ✗ Skipping game 409133 - failed validation
#   Scraping game 185/6051: ID 409134
#     ✗ Skipping game 409134 - failed validation
#   Scraping game 186/6051: ID 409135
#     ✗ Skipping game 409135 - failed validation
#   Scraping game 187/6051: ID 409136
#     ✗ Skipping game 409136 - failed validation
#   Scraping game 188/6051: ID 409137
#     ✗ Skipping game 409137 - failed validation
#   Scraping game 189/6051: ID 409138
#     ✗ Skipping game 409138 - failed validation
#   Scraping game 190/6051: ID 409139
#     ✗ Skipping game 409139 - failed validation
#   Scraping game 191/6051: ID 409140
#     ✗ Skipping game 409140 - failed validation
#   Scraping game 192/6051: ID 409141
#     ✗ Skipping game 409141 - failed validation
#   Scraping game 193/6051: ID 409142
#     ✗ Skipping game 409142 - failed validation
#   Scraping game 194/6051: ID 409143
#     ✗ Skipping game 409143 - failed validation
#   Scraping game 195/6051: ID 409144
#     ✗ Skipping game 409144 - failed validation
#   Scraping game 196/6051: ID 409145
#     ✗ Skipping game 409145 - failed validation
#   Scraping game 197/6051: ID 409146
#     ✗ Skipping game 409146 - failed validation
#   Scraping game 198/6051: ID 409147
#     ✗ Skipping game 409147 - failed validation
#   Scraping game 199/6051: ID 409148
#     ✗ Skipping game 409148 - failed validation
#   Scraping game 200/6051: ID 409149
#     ✗ Skipping game 409149 - failed validation
#
# Processing batch 3: games 201-300
#   Scraping game 201/6051: ID 409150
#     ✗ Skipping game 409150 - failed validation
#   Scraping game 202/6051: ID 409151
#     ✗ Skipping game 409151 - failed validation
#   Scraping game 203/6051: ID 409152
#     ✗ Skipping game 409152 - failed validation
#   Scraping game 204/6051: ID 409153
#     ✗ Skipping game 409153 - failed validation
#   Scraping game 205/6051: ID 409154
#     ✗ Skipping game 409154 - failed validation
#   Scraping game 206/6051: ID 409155
#     ✗ Skipping game 409155 - failed validation
#   Scraping game 207/6051: ID 409156
#     ✗ Skipping game 409156 - failed validation
#   Scraping game 208/6051: ID 409157
#     ✗ Skipping game 409157 - failed validation
#   Scraping game 209/6051: ID 409158
#     ✗ Skipping game 409158 - failed validation
#   Scraping game 210/6051: ID 409159
#     ✗ Skipping game 409159 - failed validation
#   Scraping game 211/6051: ID 409160
#     ✗ Skipping game 409160 - failed validation
#   Scraping game 212/6051: ID 409161
#     Rejecting game 409161 - null/empty field: bgg_rank
#     ✗ Skipping game 409161 - failed validation
#   Scraping game 213/6051: ID 409162
#     ✗ Skipping game 409162 - failed validation
#   Scraping game 214/6051: ID 409163
#     ✗ Skipping game 409163 - failed validation
#   Scraping game 215/6051: ID 409164
#     ✗ Skipping game 409164 - failed validation
#   Scraping game 216/6051: ID 409165
#     ✗ Skipping game 409165 - failed validation
#   Scraping game 217/6051: ID 409166
#     ✗ Skipping game 409166 - failed validation
#   Scraping game 218/6051: ID 409167
#     ✗ Skipping game 409167 - failed validation
#   Scraping game 219/6051: ID 409168
#     Rejecting game 409168 - null/empty field: mechanisms
#     ✗ Skipping game 409168 - failed validation
#   Scraping game 220/6051: ID 409169
#     ✗ Skipping game 409169 - failed validation
#   Scraping game 221/6051: ID 409170
#     Rejecting game 409170 - null/empty field: bgg_rank
#     ✗ Skipping game 409170 - failed validation
#   Scraping game 222/6051: ID 409171
#     Rejecting game 409171 - null/empty field: mechanisms
#     ✗ Skipping game 409171 - failed validation
#   Scraping game 223/6051: ID 409172
#     ✗ Skipping game 409172 - failed validation
#   Scraping game 224/6051: ID 409173
#     ✗ Skipping game 409173 - failed validation
#   Scraping game 225/6051: ID 409174
#     ✗ Skipping game 409174 - failed validation
#   Scraping game 226/6051: ID 409175
#     ✗ Skipping game 409175 - failed validation
#   Scraping game 227/6051: ID 409176
#     ✗ Skipping game 409176 - failed validation
#   Scraping game 228/6051: ID 409177
#     ✗ Skipping game 409177 - failed validation
#   Scraping game 229/6051: ID 409178
#     ✗ Skipping game 409178 - failed validation
#   Scraping game 230/6051: ID 409179
#     ✗ Skipping game 409179 - failed validation
#   Scraping game 231/6051: ID 409180
#     ✗ Skipping game 409180 - failed validation
#   Scraping game 232/6051: ID 409181
#     ✗ Skipping game 409181 - failed validation
#   Scraping game 233/6051: ID 409182
#     ✗ Skipping game 409182 - failed validation
#   Scraping game 234/6051: ID 409183
#     ✗ Skipping game 409183 - failed validation
#   Scraping game 235/6051: ID 409184
#     ✗ Skipping game 409184 - failed validation
#   Scraping game 236/6051: ID 409185
#     ✗ Skipping game 409185 - failed validation
#   Scraping game 237/6051: ID 409186
#     Rejecting game 409186 - null/empty field: mechanisms
#     ✗ Skipping game 409186 - failed validation
#   Scraping game 238/6051: ID 409187
#     Rejecting game 409187 - null/empty field: artists
#     ✗ Skipping game 409187 - failed validation
#   Scraping game 239/6051: ID 409188
#     Rejecting game 409188 - null/empty field: mechanisms
#     ✗ Skipping game 409188 - failed validation
#   Scraping game 240/6051: ID 409189
#     Rejecting game 409189 - null/empty field: artists
#     ✗ Skipping game 409189 - failed validation
#   Scraping game 241/6051: ID 409190
#     Rejecting game 409190 - null/empty field: bgg_rank
#     ✗ Skipping game 409190 - failed validation
#   Scraping game 242/6051: ID 409191
#     ✗ Skipping game 409191 - failed validation
#   Scraping game 243/6051: ID 409192
#     ✗ Skipping game 409192 - failed validation
#   Scraping game 244/6051: ID 409193
#     ✗ Skipping game 409193 - failed validation
#   Scraping game 245/6051: ID 409194
#     ✗ Skipping game 409194 - failed validation
#   Scraping game 246/6051: ID 409195
#     ✗ Skipping game 409195 - failed validation
#   Scraping game 247/6051: ID 409196
#     ✗ Skipping game 409196 - failed validation
#   Scraping game 248/6051: ID 409197
#     ✗ Skipping game 409197 - failed validation
#   Scraping game 249/6051: ID 409198
#     ✗ Skipping game 409198 - failed validation
#   Scraping game 250/6051: ID 409199
#     ✗ Skipping game 409199 - failed validation
#   Scraping game 251/6051: ID 409200
#     ✗ Skipping game 409200 - failed validation
#   Scraping game 252/6051: ID 409201
#     ✗ Skipping game 409201 - failed validation
#   Scraping game 253/6051: ID 409202
#     ✗ Skipping game 409202 - failed validation
#   Scraping game 254/6051: ID 409203
#     ✗ Skipping game 409203 - failed validation
#   Scraping game 255/6051: ID 409204
#     ✗ Skipping game 409204 - failed validation
#   Scraping game 256/6051: ID 409205
#     ✗ Skipping game 409205 - failed validation
#   Scraping game 257/6051: ID 409206
#     ✗ Skipping game 409206 - failed validation
#   Scraping game 258/6051: ID 409207
#     ✗ Skipping game 409207 - failed validation
#   Scraping game 259/6051: ID 409208
#     ✗ Skipping game 409208 - failed validation
#   Scraping game 260/6051: ID 409209
#     ✗ Skipping game 409209 - failed validation
#   Scraping game 261/6051: ID 409210
#     ✗ Skipping game 409210 - failed validation
#   Scraping game 262/6051: ID 409211
#     ✗ Skipping game 409211 - failed validation
#   Scraping game 263/6051: ID 409212
#     ✗ Skipping game 409212 - failed validation
#   Scraping game 264/6051: ID 409213
#     ✗ Skipping game 409213 - failed validation
#   Scraping game 265/6051: ID 409214
#     ✗ Skipping game 409214 - failed validation
#   Scraping game 266/6051: ID 409215
#     ✗ Skipping game 409215 - failed validation
#   Scraping game 267/6051: ID 409216
#     ✗ Skipping game 409216 - failed validation
#   Scraping game 268/6051: ID 409217
#     ✗ Skipping game 409217 - failed validation
#   Scraping game 269/6051: ID 409218
#     ✗ Skipping game 409218 - failed validation
#   Scraping game 270/6051: ID 409219
#     ✗ Skipping game 409219 - failed validation
#   Scraping game 271/6051: ID 409220
#     ✗ Skipping game 409220 - failed validation
#   Scraping game 272/6051: ID 409221
#     ✗ Skipping game 409221 - failed validation
#   Scraping game 273/6051: ID 409222
#     ✗ Skipping game 409222 - failed validation
#   Scraping game 274/6051: ID 409223
#     ✗ Skipping game 409223 - failed validation
#   Scraping game 275/6051: ID 409224
#     ✗ Skipping game 409224 - failed validation
#   Scraping game 276/6051: ID 409225
#     ✗ Skipping game 409225 - failed validation
#   Scraping game 277/6051: ID 409226
#     ✗ Skipping game 409226 - failed validation
#   Scraping game 278/6051: ID 409227
#     ✗ Skipping game 409227 - failed validation
#   Scraping game 279/6051: ID 409228
#     ✗ Skipping game 409228 - failed validation
#   Scraping game 280/6051: ID 409229
#     ✗ Skipping game 409229 - failed validation
#   Scraping game 281/6051: ID 409230
#     ✗ Skipping game 409230 - failed validation
#   Scraping game 282/6051: ID 409231
#     ✗ Skipping game 409231 - failed validation
#   Scraping game 283/6051: ID 409232
#     ✗ Skipping game 409232 - failed validation
#   Scraping game 284/6051: ID 409233
#     ✗ Skipping game 409233 - failed validation
#   Scraping game 285/6051: ID 409234
#     ✗ Skipping game 409234 - failed validation
#   Scraping game 286/6051: ID 409235
#     ✗ Skipping game 409235 - failed validation
#   Scraping game 287/6051: ID 409236
#     ✗ Skipping game 409236 - failed validation
#   Scraping game 288/6051: ID 409237
#     ✗ Skipping game 409237 - failed validation
#   Scraping game 289/6051: ID 409238
#     ✗ Skipping game 409238 - failed validation
#   Scraping game 290/6051: ID 409239
#     ✗ Skipping game 409239 - failed validation
#   Scraping game 291/6051: ID 409240
#     ✗ Skipping game 409240 - failed validation
#   Scraping game 292/6051: ID 409241
#     ✗ Skipping game 409241 - failed validation
#   Scraping game 293/6051: ID 409242
#     ✗ Skipping game 409242 - failed validation
#   Scraping game 294/6051: ID 409243
#     ✗ Skipping game 409243 - failed validation
#   Scraping game 295/6051: ID 409244
#     Rejecting game 409244 - null/empty field: designers
#     ✗ Skipping game 409244 - failed validation
#   Scraping game 296/6051: ID 409245
#     ✗ Skipping game 409245 - failed validation
#   Scraping game 297/6051: ID 409246
#     ✗ Skipping game 409246 - failed validation
#   Scraping game 298/6051: ID 409247
#     ✗ Skipping game 409247 - failed validation
#   Scraping game 299/6051: ID 409248
#     ✗ Skipping game 409248 - failed validation
#   Scraping game 300/6051: ID 409249
#     ✗ Skipping game 409249 - failed validation
#
# Processing batch 4: games 301-400
#   Scraping game 301/6051: ID 409250
#     ✗ Skipping game 409250 - failed validation
#   Scraping game 302/6051: ID 409251
#     ✗ Skipping game 409251 - failed validation
#   Scraping game 303/6051: ID 409252
#     ✗ Skipping game 409252 - failed validation
#   Scraping game 304/6051: ID 409253
#     ✗ Skipping game 409253 - failed validation
#   Scraping game 305/6051: ID 409254
#     ✗ Skipping game 409254 - failed validation
#   Scraping game 306/6051: ID 409255
#     ✗ Skipping game 409255 - failed validation
#   Scraping game 307/6051: ID 409256
#     ✗ Skipping game 409256 - failed validation
#   Scraping game 308/6051: ID 409257
#     ✗ Skipping game 409257 - failed validation
#   Scraping game 309/6051: ID 409258
#     ✗ Skipping game 409258 - failed validation
#   Scraping game 310/6051: ID 409259
#     ✗ Skipping game 409259 - failed validation
#   Scraping game 311/6051: ID 409260
#     ✗ Skipping game 409260 - failed validation
#   Scraping game 312/6051: ID 409261
#     ✗ Skipping game 409261 - failed validation
#   Scraping game 313/6051: ID 409262
#     ✗ Skipping game 409262 - failed validation
#   Scraping game 314/6051: ID 409263
#     ✗ Skipping game 409263 - failed validation
#   Scraping game 315/6051: ID 409264
#     ✗ Skipping game 409264 - failed validation
#   Scraping game 316/6051: ID 409265
#     ✗ Skipping game 409265 - failed validation
#   Scraping game 317/6051: ID 409266
#     ✗ Skipping game 409266 - failed validation
#   Scraping game 318/6051: ID 409267
#     ✗ Skipping game 409267 - failed validation
#   Scraping game 319/6051: ID 409268
#     ✗ Skipping game 409268 - failed validation
#   Scraping game 320/6051: ID 409269
#     ✗ Skipping game 409269 - failed validation
#   Scraping game 321/6051: ID 409270
#     ✗ Skipping game 409270 - failed validation
#   Scraping game 322/6051: ID 409271
#     ✗ Skipping game 409271 - failed validation
#   Scraping game 323/6051: ID 409272
#     ✗ Skipping game 409272 - failed validation
#   Scraping game 324/6051: ID 409273
#     ✗ Skipping game 409273 - failed validation
#   Scraping game 325/6051: ID 409274
#     ✗ Skipping game 409274 - failed validation
#   Scraping game 326/6051: ID 409275
#     Rejecting game 409275 - null/empty field: artists
#     ✗ Skipping game 409275 - failed validation
#   Scraping game 327/6051: ID 409276
#     ✗ Skipping game 409276 - failed validation
#   Scraping game 328/6051: ID 409277
#     Rejecting game 409277 - null/empty field: bgg_rank
#     ✗ Skipping game 409277 - failed validation
#   Scraping game 329/6051: ID 409278
#     ✗ Skipping game 409278 - failed validation
#   Scraping game 330/6051: ID 409279
#     ✗ Skipping game 409279 - failed validation
#   Scraping game 331/6051: ID 409280
#     ✗ Skipping game 409280 - failed validation
#   Scraping game 332/6051: ID 409281
#     ✗ Skipping game 409281 - failed validation
#   Scraping game 333/6051: ID 409282
#     ✗ Skipping game 409282 - failed validation
#   Scraping game 334/6051: ID 409283
#     ✗ Skipping game 409283 - failed validation
#   Scraping game 335/6051: ID 409284
#     ✗ Skipping game 409284 - failed validation
#   Scraping game 336/6051: ID 409285
#     ✗ Skipping game 409285 - failed validation
#   Scraping game 337/6051: ID 409286
#     ✗ Skipping game 409286 - failed validation
#   Scraping game 338/6051: ID 409287
#     ✗ Skipping game 409287 - failed validation
#   Scraping game 339/6051: ID 409288
#     ✗ Skipping game 409288 - failed validation
#   Scraping game 340/6051: ID 409289
#     ✗ Skipping game 409289 - failed validation
#   Scraping game 341/6051: ID 409290
#     ✗ Skipping game 409290 - failed validation
#   Scraping game 342/6051: ID 409291
#     ✗ Skipping game 409291 - failed validation
#   Scraping game 343/6051: ID 409292
#     ✗ Skipping game 409292 - failed validation
#   Scraping game 344/6051: ID 409293
#     ✗ Skipping game 409293 - failed validation
#   Scraping game 345/6051: ID 409294
#     ✗ Skipping game 409294 - failed validation
#   Scraping game 346/6051: ID 409295
#     ✗ Skipping game 409295 - failed validation
#   Scraping game 347/6051: ID 409296
#     ✗ Skipping game 409296 - failed validation
#   Scraping game 348/6051: ID 409297
#     ✗ Skipping game 409297 - failed validation
#   Scraping game 349/6051: ID 409298
#     ✗ Skipping game 409298 - failed validation
#   Scraping game 350/6051: ID 409299
#     ✗ Skipping game 409299 - failed validation
#   Scraping game 351/6051: ID 409300
#     ✗ Skipping game 409300 - failed validation
#   Scraping game 352/6051: ID 409301
#     ✗ Skipping game 409301 - failed validation
#   Scraping game 353/6051: ID 409302
#     Rejecting game 409302 - null/empty field: designers
#     ✗ Skipping game 409302 - failed validation
#   Scraping game 354/6051: ID 409303
#     ✗ Skipping game 409303 - failed validation
#   Scraping game 355/6051: ID 409304
#     ✗ Skipping game 409304 - failed validation
#   Scraping game 356/6051: ID 409305
#     ✗ Skipping game 409305 - failed validation
#   Scraping game 357/6051: ID 409306
#     ✗ Skipping game 409306 - failed validation
#   Scraping game 358/6051: ID 409307
#     ✗ Skipping game 409307 - failed validation
#   Scraping game 359/6051: ID 409308
#     ✗ Skipping game 409308 - failed validation
#   Scraping game 360/6051: ID 409309
#     ✗ Skipping game 409309 - failed validation
#   Scraping game 361/6051: ID 409310
#     ✗ Skipping game 409310 - failed validation
#   Scraping game 362/6051: ID 409311
#     ✗ Skipping game 409311 - failed validation
#   Scraping game 363/6051: ID 409312
#     ✗ Skipping game 409312 - failed validation
#   Scraping game 364/6051: ID 409313
#     ✗ Skipping game 409313 - failed validation
#   Scraping game 365/6051: ID 409314
#     ✗ Skipping game 409314 - failed validation
#   Scraping game 366/6051: ID 409315
#     ✗ Skipping game 409315 - failed validation
#   Scraping game 367/6051: ID 409316
#     ✗ Skipping game 409316 - failed validation
#   Scraping game 368/6051: ID 409317
#     ✗ Skipping game 409317 - failed validation
#   Scraping game 369/6051: ID 409318
#     ✗ Skipping game 409318 - failed validation
#   Scraping game 370/6051: ID 409319
#     ✗ Skipping game 409319 - failed validation
#   Scraping game 371/6051: ID 409320
#     ✗ Skipping game 409320 - failed validation
#   Scraping game 372/6051: ID 409321
#     ✗ Skipping game 409321 - failed validation
#   Scraping game 373/6051: ID 409322
#     Rejecting game 409322 - null/empty field: bgg_rank
#     ✗ Skipping game 409322 - failed validation
#   Scraping game 374/6051: ID 409323
#     ✗ Skipping game 409323 - failed validation
#   Scraping game 375/6051: ID 409324
#     Rejecting game 409324 - null/empty field: bgg_rank
#     ✗ Skipping game 409324 - failed validation
#   Scraping game 376/6051: ID 409325
#     ✗ Skipping game 409325 - failed validation
#   Scraping game 377/6051: ID 409326
#     ✗ Skipping game 409326 - failed validation
#   Scraping game 378/6051: ID 409327
#     ✗ Skipping game 409327 - failed validation
#   Scraping game 379/6051: ID 409328
#     ✗ Skipping game 409328 - failed validation
#   Scraping game 380/6051: ID 409329
#     Rejecting game 409329 - null/empty field: categories
#     ✗ Skipping game 409329 - failed validation
#   Scraping game 381/6051: ID 409330
#     ✗ Skipping game 409330 - failed validation
#   Scraping game 382/6051: ID 409331
#     Rejecting game 409331 - null/empty field: artists
#     ✗ Skipping game 409331 - failed validation
#   Scraping game 383/6051: ID 409332
#     ✗ Skipping game 409332 - failed validation
#   Scraping game 384/6051: ID 409333
#     ✗ Skipping game 409333 - failed validation
#   Scraping game 385/6051: ID 409334
#     ✗ Skipping game 409334 - failed validation
#   Scraping game 386/6051: ID 409335
#     ✗ Skipping game 409335 - failed validation
#   Scraping game 387/6051: ID 409336
#     ✗ Skipping game 409336 - failed validation
#   Scraping game 388/6051: ID 409337
#     ✗ Skipping game 409337 - failed validation
#   Scraping game 389/6051: ID 409338
#     ✗ Skipping game 409338 - failed validation
#   Scraping game 390/6051: ID 409339
#     ✗ Skipping game 409339 - failed validation
#   Scraping game 391/6051: ID 409340
#     ✗ Skipping game 409340 - failed validation
#   Scraping game 392/6051: ID 409341
#     Rejecting game 409341 - null/empty field: designers
#     ✗ Skipping game 409341 - failed validation
#   Scraping game 393/6051: ID 409342
#     ✗ Skipping game 409342 - failed validation
#   Scraping game 394/6051: ID 409343
#     Rejecting game 409343 - null/empty field: designers
#     ✗ Skipping game 409343 - failed validation
#   Scraping game 395/6051: ID 409344
#     ✗ Skipping game 409344 - failed validation
#   Scraping game 396/6051: ID 409345
#     ✗ Skipping game 409345 - failed validation
#   Scraping game 397/6051: ID 409346
#     ✗ Skipping game 409346 - failed validation
#   Scraping game 398/6051: ID 409347
#     ✗ Skipping game 409347 - failed validation
#   Scraping game 399/6051: ID 409348
#     ✗ Skipping game 409348 - failed validation
#   Scraping game 400/6051: ID 409349
#     ✗ Skipping game 409349 - failed validation
#
# Processing batch 5: games 401-500
#   Scraping game 401/6051: ID 409350
#     ✗ Skipping game 409350 - failed validation
#   Scraping game 402/6051: ID 409351
#     ✗ Skipping game 409351 - failed validation
#   Scraping game 403/6051: ID 409352
#     ✗ Skipping game 409352 - failed validation
#   Scraping game 404/6051: ID 409353
#     ✗ Skipping game 409353 - failed validation
#   Scraping game 405/6051: ID 409354
#     ✗ Skipping game 409354 - failed validation
#   Scraping game 406/6051: ID 409355
#     ✗ Skipping game 409355 - failed validation
#   Scraping game 407/6051: ID 409356
#     ✗ Skipping game 409356 - failed validation
#   Scraping game 408/6051: ID 409357
#     Rejecting game 409357 - null/empty field: artists
#     ✗ Skipping game 409357 - failed validation
#   Scraping game 409/6051: ID 409358
#     ✗ Skipping game 409358 - failed validation
#   Scraping game 410/6051: ID 409359
#     ✗ Skipping game 409359 - failed validation
#   Scraping game 411/6051: ID 409360
#     ✗ Skipping game 409360 - failed validation
#   Scraping game 412/6051: ID 409361
#     ✗ Skipping game 409361 - failed validation
#   Scraping game 413/6051: ID 409362
#     Rejecting game 409362 - null/empty field: designers
#     ✗ Skipping game 409362 - failed validation
#   Scraping game 414/6051: ID 409363
#     ✗ Skipping game 409363 - failed validation
#   Scraping game 415/6051: ID 409364
#     ✗ Skipping game 409364 - failed validation
#   Scraping game 416/6051: ID 409365
#     ✗ Skipping game 409365 - failed validation
#   Scraping game 417/6051: ID 409366
#     ✗ Skipping game 409366 - failed validation
#   Scraping game 418/6051: ID 409367
#     ✗ Skipping game 409367 - failed validation
#   Scraping game 419/6051: ID 409368
#     ✗ Skipping game 409368 - failed validation
#   Scraping game 420/6051: ID 409369
#     ✗ Skipping game 409369 - failed validation
#   Scraping game 421/6051: ID 409370
#     ✗ Skipping game 409370 - failed validation
#   Scraping game 422/6051: ID 409371
#     ✗ Skipping game 409371 - failed validation
#   Scraping game 423/6051: ID 409372
#     ✗ Skipping game 409372 - failed validation
#   Scraping game 424/6051: ID 409373
#     ✗ Skipping game 409373 - failed validation
#   Scraping game 425/6051: ID 409374
#     ✗ Skipping game 409374 - failed validation
#   Scraping game 426/6051: ID 409375
#     ✗ Skipping game 409375 - failed validation
#   Scraping game 427/6051: ID 409376
#     ✗ Skipping game 409376 - failed validation
#   Scraping game 428/6051: ID 409377
#     ✗ Skipping game 409377 - failed validation
#   Scraping game 429/6051: ID 409378
#     ✗ Skipping game 409378 - failed validation
#   Scraping game 430/6051: ID 409379
#     ✗ Skipping game 409379 - failed validation
#   Scraping game 431/6051: ID 409380
#     ✗ Skipping game 409380 - failed validation
#   Scraping game 432/6051: ID 409381
#     ✗ Skipping game 409381 - failed validation
#   Scraping game 433/6051: ID 409382
#     ✗ Skipping game 409382 - failed validation
#   Scraping game 434/6051: ID 409383
#     ✗ Skipping game 409383 - failed validation
#   Scraping game 435/6051: ID 409384
#     ✗ Skipping game 409384 - failed validation
#   Scraping game 436/6051: ID 409385
#     ✗ Skipping game 409385 - failed validation
#   Scraping game 437/6051: ID 409386
#     ✗ Skipping game 409386 - failed validation
#   Scraping game 438/6051: ID 409387
#     ✗ Skipping game 409387 - failed validation
#   Scraping game 439/6051: ID 409388
#     ✗ Skipping game 409388 - failed validation
#   Scraping game 440/6051: ID 409389
#     ✗ Skipping game 409389 - failed validation
#   Scraping game 441/6051: ID 409390
#     ✗ Skipping game 409390 - failed validation
#   Scraping game 442/6051: ID 409391
#     ✗ Skipping game 409391 - failed validation
#   Scraping game 443/6051: ID 409392
#     ✗ Skipping game 409392 - failed validation
#   Scraping game 444/6051: ID 409393
#     ✗ Skipping game 409393 - failed validation
#   Scraping game 445/6051: ID 409394
#     ✗ Skipping game 409394 - failed validation
#   Scraping game 446/6051: ID 409395
#     ✗ Skipping game 409395 - failed validation
#   Scraping game 447/6051: ID 409396
#     ✗ Skipping game 409396 - failed validation
#   Scraping game 448/6051: ID 409397
#     ✗ Skipping game 409397 - failed validation
#   Scraping game 449/6051: ID 409398
#     ✗ Skipping game 409398 - failed validation
#   Scraping game 450/6051: ID 409399
#     ✗ Skipping game 409399 - failed validation
#   Scraping game 451/6051: ID 409400
#     ✗ Skipping game 409400 - failed validation
#   Scraping game 452/6051: ID 409401
#     ✗ Skipping game 409401 - failed validation
#   Scraping game 453/6051: ID 409402
#     ✗ Skipping game 409402 - failed validation
#   Scraping game 454/6051: ID 409403
#     ✗ Skipping game 409403 - failed validation
#   Scraping game 455/6051: ID 409404
#     ✗ Skipping game 409404 - failed validation
#   Scraping game 456/6051: ID 409405
#     ✗ Skipping game 409405 - failed validation
#   Scraping game 457/6051: ID 409406
#     ✗ Skipping game 409406 - failed validation
#   Scraping game 458/6051: ID 409407
#     ✗ Skipping game 409407 - failed validation
#   Scraping game 459/6051: ID 409408
#     ✗ Skipping game 409408 - failed validation
#   Scraping game 460/6051: ID 409409
#     ✗ Skipping game 409409 - failed validation
#   Scraping game 461/6051: ID 409410
#     ✗ Skipping game 409410 - failed validation
#   Scraping game 462/6051: ID 409411
#     ✗ Skipping game 409411 - failed validation
#   Scraping game 463/6051: ID 409412
#     ✗ Skipping game 409412 - failed validation
#   Scraping game 464/6051: ID 409413
#     ✗ Skipping game 409413 - failed validation
#   Scraping game 465/6051: ID 409414
#     ✗ Skipping game 409414 - failed validation
#   Scraping game 466/6051: ID 409415
#     ✗ Skipping game 409415 - failed validation
#   Scraping game 467/6051: ID 409416
#     ✗ Skipping game 409416 - failed validation
#   Scraping game 468/6051: ID 409417
#     ✗ Skipping game 409417 - failed validation
#   Scraping game 469/6051: ID 409418
#     ✗ Skipping game 409418 - failed validation
#   Scraping game 470/6051: ID 409419
#     ✗ Skipping game 409419 - failed validation
#   Scraping game 471/6051: ID 409420
#     ✗ Skipping game 409420 - failed validation
#   Scraping game 472/6051: ID 409421
#     ✗ Skipping game 409421 - failed validation
#   Scraping game 473/6051: ID 409422
#     ✗ Skipping game 409422 - failed validation
#   Scraping game 474/6051: ID 409423
#     ✗ Skipping game 409423 - failed validation
#   Scraping game 475/6051: ID 409424
#     ✗ Skipping game 409424 - failed validation
#   Scraping game 476/6051: ID 409425
#     ✗ Skipping game 409425 - failed validation
#   Scraping game 477/6051: ID 409426
#     ✗ Skipping game 409426 - failed validation
#   Scraping game 478/6051: ID 409427
#     ✗ Skipping game 409427 - failed validation
#   Scraping game 479/6051: ID 409428
#     ✗ Skipping game 409428 - failed validation
#   Scraping game 480/6051: ID 409429
#     ✗ Skipping game 409429 - failed validation
#   Scraping game 481/6051: ID 409430
#     ✗ Skipping game 409430 - failed validation
#   Scraping game 482/6051: ID 409431
#     ✗ Skipping game 409431 - failed validation
#   Scraping game 483/6051: ID 409432
#     ✗ Skipping game 409432 - failed validation
#   Scraping game 484/6051: ID 409433
#     ✗ Skipping game 409433 - failed validation
#   Scraping game 485/6051: ID 409434
#     ✗ Skipping game 409434 - failed validation
#   Scraping game 486/6051: ID 409435
#     ✗ Skipping game 409435 - failed validation
#   Scraping game 487/6051: ID 409436
#     Rejecting game 409436 - null/empty field: bgg_rank
#     ✗ Skipping game 409436 - failed validation
#   Scraping game 488/6051: ID 409437
#     ✗ Skipping game 409437 - failed validation
#   Scraping game 489/6051: ID 409438
#     ✗ Skipping game 409438 - failed validation
#   Scraping game 490/6051: ID 409439
#     ✗ Skipping game 409439 - failed validation
#   Scraping game 491/6051: ID 409440
#     ✗ Skipping game 409440 - failed validation
#   Scraping game 492/6051: ID 409441
#     ✗ Skipping game 409441 - failed validation
#   Scraping game 493/6051: ID 409442
#     ✗ Skipping game 409442 - failed validation
#   Scraping game 494/6051: ID 409443
#     ✗ Skipping game 409443 - failed validation
#   Scraping game 495/6051: ID 409444
#     ✗ Skipping game 409444 - failed validation
#   Scraping game 496/6051: ID 409445
#     ✗ Skipping game 409445 - failed validation
#   Scraping game 497/6051: ID 409446
#     ✗ Skipping game 409446 - failed validation
#   Scraping game 498/6051: ID 409447
#     ✗ Skipping game 409447 - failed validation
#   Scraping game 499/6051: ID 409448
#     ✗ Skipping game 409448 - failed validation
#   Scraping game 500/6051: ID 409449
#     ✗ Skipping game 409449 - failed validation
#
# Processing batch 6: games 501-600
#   Scraping game 501/6051: ID 409450
#     ✗ Skipping game 409450 - failed validation
#   Scraping game 502/6051: ID 409451
#     ✗ Skipping game 409451 - failed validation
#   Scraping game 503/6051: ID 409452
#     ✗ Skipping game 409452 - failed validation
#   Scraping game 504/6051: ID 409453
#     ✗ Skipping game 409453 - failed validation
#   Scraping game 505/6051: ID 409454
#     ✗ Skipping game 409454 - failed validation
#   Scraping game 506/6051: ID 409455
#     ✗ Skipping game 409455 - failed validation
#   Scraping game 507/6051: ID 409456
#     ✗ Skipping game 409456 - failed validation
#   Scraping game 508/6051: ID 409457
#     ✗ Skipping game 409457 - failed validation
#   Scraping game 509/6051: ID 409458
#     ✗ Skipping game 409458 - failed validation
#   Scraping game 510/6051: ID 409459
#     ✗ Skipping game 409459 - failed validation
#   Scraping game 511/6051: ID 409460
#     ✗ Skipping game 409460 - failed validation
#   Scraping game 512/6051: ID 409461
#     ✗ Skipping game 409461 - failed validation
#   Scraping game 513/6051: ID 409462
#     ✗ Skipping game 409462 - failed validation
#   Scraping game 514/6051: ID 409463
#     ✗ Skipping game 409463 - failed validation
#   Scraping game 515/6051: ID 409464
#     ✗ Skipping game 409464 - failed validation
#   Scraping game 516/6051: ID 409465
#     ✗ Skipping game 409465 - failed validation
#   Scraping game 517/6051: ID 409466
#     ✗ Skipping game 409466 - failed validation
#   Scraping game 518/6051: ID 409467
#     ✗ Skipping game 409467 - failed validation
#   Scraping game 519/6051: ID 409468
#     ✗ Skipping game 409468 - failed validation
#   Scraping game 520/6051: ID 409469
#     ✗ Skipping game 409469 - failed validation
#   Scraping game 521/6051: ID 409470
#     ✗ Skipping game 409470 - failed validation
#   Scraping game 522/6051: ID 409471
#     ✗ Skipping game 409471 - failed validation
#   Scraping game 523/6051: ID 409472
#     Rejecting game 409472 - null/empty field: designers
#     ✗ Skipping game 409472 - failed validation
#   Scraping game 524/6051: ID 409473
#     Rejecting game 409473 - null/empty field: mechanisms
#     ✗ Skipping game 409473 - failed validation
#   Scraping game 525/6051: ID 409474
#     ✗ Skipping game 409474 - failed validation
#   Scraping game 526/6051: ID 409475
#     ✗ Skipping game 409475 - failed validation
#   Scraping game 527/6051: ID 409476
#     ✗ Skipping game 409476 - failed validation
#   Scraping game 528/6051: ID 409477
#     ✗ Skipping game 409477 - failed validation
#   Scraping game 529/6051: ID 409478
#     ✗ Skipping game 409478 - failed validation
#   Scraping game 530/6051: ID 409479
#     ✗ Skipping game 409479 - failed validation
#   Scraping game 531/6051: ID 409480
#     ✗ Skipping game 409480 - failed validation
#   Scraping game 532/6051: ID 409481
#     Rejecting game 409481 - null/empty field: bgg_rank
#     ✗ Skipping game 409481 - failed validation
#   Scraping game 533/6051: ID 409482
#     Rejecting game 409482 - null/empty field: artists
#     ✗ Skipping game 409482 - failed validation
#   Scraping game 534/6051: ID 409483
# ...
#     ✗ Skipping game 414849 - failed validation
#
# Processing batch 60: games 5901-6000
#   Scraping game 5901/6051: ID 414850
#     Rejecting game 414850 - null/empty field: mechanisms
#     ✗ Skipping game 414850 - failed validation
#   Scraping game 5902/6051: ID 414851
#     ✗ Skipping game 414851 - failed validation
#   Scraping game 5903/6051: ID 414852
#     Rejecting game 414852 - null/empty field: artists
#     ✗ Skipping game 414852 - failed validation
#   Scraping game 5904/6051: ID 414853
#     Rejecting game 414853 - null/empty field: mechanisms
#     ✗ Skipping game 414853 - failed validation
#   Scraping game 5905/6051: ID 414854
#     ✗ Skipping game 414854 - failed validation
#   Scraping game 5906/6051: ID 414855
#     Rejecting game 414855 - null/empty field: category_ranks
#     ✗ Skipping game 414855 - failed validation
#   Scraping game 5907/6051: ID 414856
#     Rejecting game 414856 - null/empty field: artists
#     ✗ Skipping game 414856 - failed validation
#   Scraping game 5908/6051: ID 414857
#     ✗ Skipping game 414857 - failed validation
#   Scraping game 5909/6051: ID 414858
#     ✗ Skipping game 414858 - failed validation
#   Scraping game 5910/6051: ID 414859
#     ✗ Skipping game 414859 - failed validation
#   Scraping game 5911/6051: ID 414860
#     ✗ Skipping game 414860 - failed validation
#   Scraping game 5912/6051: ID 414861
#     Rejecting game 414861 - null/empty field: artists
#     ✗ Skipping game 414861 - failed validation
#   Scraping game 5913/6051: ID 414862
#     Rejecting game 414862 - null/empty field: designers
#     ✗ Skipping game 414862 - failed validation
#   Scraping game 5914/6051: ID 414863
#     ✗ Skipping game 414863 - failed validation
#   Scraping game 5915/6051: ID 414864
#     Rejecting game 414864 - null/empty field: bgg_rank
#     ✗ Skipping game 414864 - failed validation
#   Scraping game 5916/6051: ID 414865
#     ✗ Skipping game 414865 - failed validation
#   Scraping game 5917/6051: ID 414866
#     Rejecting game 414866 - null/empty field: bgg_rank
#     ✗ Skipping game 414866 - failed validation
#   Scraping game 5918/6051: ID 414867
#     ✗ Skipping game 414867 - failed validation
#   Scraping game 5919/6051: ID 414868
#     ✗ Skipping game 414868 - failed validation
#   Scraping game 5920/6051: ID 414869
#     ✗ Skipping game 414869 - failed validation
#   Scraping game 5921/6051: ID 414870
#     ✗ Skipping game 414870 - failed validation
#   Scraping game 5922/6051: ID 414871
#     ✗ Skipping game 414871 - failed validation
#   Scraping game 5923/6051: ID 414872
#     ✗ Skipping game 414872 - failed validation
#   Scraping game 5924/6051: ID 414873
#     ✗ Skipping game 414873 - failed validation
#   Scraping game 5925/6051: ID 414874
#     ✗ Skipping game 414874 - failed validation
#   Scraping game 5926/6051: ID 414875
#     ✗ Skipping game 414875 - failed validation
#   Scraping game 5927/6051: ID 414876
#     Rejecting game 414876 - null/empty field: bgg_rank
#     ✗ Skipping game 414876 - failed validation
#   Scraping game 5928/6051: ID 414877
#     ✗ Skipping game 414877 - failed validation
#   Scraping game 5929/6051: ID 414878
#     ✗ Skipping game 414878 - failed validation
#   Scraping game 5930/6051: ID 414879
#     ✗ Skipping game 414879 - failed validation
#   Scraping game 5931/6051: ID 414880
#     ✗ Skipping game 414880 - failed validation
#   Scraping game 5932/6051: ID 414881
#     ✗ Skipping game 414881 - failed validation
#   Scraping game 5933/6051: ID 414882
#     ✗ Skipping game 414882 - failed validation
#   Scraping game 5934/6051: ID 414883
#     ✗ Skipping game 414883 - failed validation
#   Scraping game 5935/6051: ID 414884
#     ✗ Skipping game 414884 - failed validation
#   Scraping game 5936/6051: ID 414885
#     Rejecting game 414885 - null/empty field: bgg_rank
#     ✗ Skipping game 414885 - failed validation
#   Scraping game 5937/6051: ID 414886
#     ✗ Skipping game 414886 - failed validation
#   Scraping game 5938/6051: ID 414887
#     ✗ Skipping game 414887 - failed validation
#   Scraping game 5939/6051: ID 414888
#     ✗ Skipping game 414888 - failed validation
#   Scraping game 5940/6051: ID 414889
#     ✗ Skipping game 414889 - failed validation
#   Scraping game 5941/6051: ID 414890
#     ✗ Skipping game 414890 - failed validation
#   Scraping game 5942/6051: ID 414891
#     ✗ Skipping game 414891 - failed validation
#   Scraping game 5943/6051: ID 414892
#     Rejecting game 414892 - null/empty field: bgg_rank
#     ✗ Skipping game 414892 - failed validation
#   Scraping game 5944/6051: ID 414893
#     ✗ Skipping game 414893 - failed validation
#   Scraping game 5945/6051: ID 414894
#     ✗ Skipping game 414894 - failed validation
#   Scraping game 5946/6051: ID 414895
#     ✗ Skipping game 414895 - failed validation
#   Scraping game 5947/6051: ID 414896
#     Rejecting game 414896 - null/empty field: mechanisms
#     ✗ Skipping game 414896 - failed validation
#   Scraping game 5948/6051: ID 414897
#     ✗ Skipping game 414897 - failed validation
#   Scraping game 5949/6051: ID 414898
#     Rejecting game 414898 - null/empty field: designers
#     ✗ Skipping game 414898 - failed validation
#   Scraping game 5950/6051: ID 414899
#     ✗ Skipping game 414899 - failed validation
#   Scraping game 5951/6051: ID 414900
#     ✗ Skipping game 414900 - failed validation
#   Scraping game 5952/6051: ID 414901
#     ✗ Skipping game 414901 - failed validation
#   Scraping game 5953/6051: ID 414902
#     ✗ Skipping game 414902 - failed validation
#   Scraping game 5954/6051: ID 414903
#     ✗ Skipping game 414903 - failed validation
#   Scraping game 5955/6051: ID 414904
#     ✗ Skipping game 414904 - failed validation
#   Scraping game 5956/6051: ID 414905
#     ✗ Skipping game 414905 - failed validation
#   Scraping game 5957/6051: ID 414906
#     ✗ Skipping game 414906 - failed validation
#   Scraping game 5958/6051: ID 414907
#     Rejecting game 414907 - null/empty field: category_ranks
#     ✗ Skipping game 414907 - failed validation
#   Scraping game 5959/6051: ID 414908
#     ✗ Skipping game 414908 - failed validation
#   Scraping game 5960/6051: ID 414909
#     ✗ Skipping game 414909 - failed validation
#   Scraping game 5961/6051: ID 414910
#     ✗ Skipping game 414910 - failed validation
#   Scraping game 5962/6051: ID 414911
#     ✗ Skipping game 414911 - failed validation
#   Scraping game 5963/6051: ID 414912
#     ✗ Skipping game 414912 - failed validation
#   Scraping game 5964/6051: ID 414913
#     ✗ Skipping game 414913 - failed validation
#   Scraping game 5965/6051: ID 414914
#     ✗ Skipping game 414914 - failed validation
#   Scraping game 5966/6051: ID 414915
#     ✗ Skipping game 414915 - failed validation
#   Scraping game 5967/6051: ID 414916
#     Rejecting game 414916 - null/empty field: artists
#     ✗ Skipping game 414916 - failed validation
#   Scraping game 5968/6051: ID 414917
#     ✗ Skipping game 414917 - failed validation
#   Scraping game 5969/6051: ID 414918
#     ✗ Skipping game 414918 - failed validation
#   Scraping game 5970/6051: ID 414919
#     ✗ Skipping game 414919 - failed validation
#   Scraping game 5971/6051: ID 414920
#     ✗ Skipping game 414920 - failed validation
#   Scraping game 5972/6051: ID 414921
#     ✗ Skipping game 414921 - failed validation
#   Scraping game 5973/6051: ID 414922
#     ✗ Skipping game 414922 - failed validation
#   Scraping game 5974/6051: ID 414923
#     ✗ Skipping game 414923 - failed validation
#   Scraping game 5975/6051: ID 414924
#     ✗ Skipping game 414924 - failed validation
#   Scraping game 5976/6051: ID 414925
#     ✗ Skipping game 414925 - failed validation
#   Scraping game 5977/6051: ID 414926
#     ✗ Skipping game 414926 - failed validation
#   Scraping game 5978/6051: ID 414927
#     Rejecting game 414927 - null/empty field: category_ranks
#     ✗ Skipping game 414927 - failed validation
#   Scraping game 5979/6051: ID 414928
#     ✗ Skipping game 414928 - failed validation
#   Scraping game 5980/6051: ID 414929
#     ✗ Skipping game 414929 - failed validation
#   Scraping game 5981/6051: ID 414930
#     ✗ Skipping game 414930 - failed validation
#   Scraping game 5982/6051: ID 414931
#     ✗ Skipping game 414931 - failed validation
#   Scraping game 5983/6051: ID 414932
#     ✗ Skipping game 414932 - failed validation
#   Scraping game 5984/6051: ID 414933
#     ✗ Skipping game 414933 - failed validation
#   Scraping game 5985/6051: ID 414934
#     ✗ Skipping game 414934 - failed validation
#   Scraping game 5986/6051: ID 414935
#     ✗ Skipping game 414935 - failed validation
#   Scraping game 5987/6051: ID 414936
#     ✗ Skipping game 414936 - failed validation
#   Scraping game 5988/6051: ID 414937
#     ✗ Skipping game 414937 - failed validation
#   Scraping game 5989/6051: ID 414938
#     ✗ Skipping game 414938 - failed validation
#   Scraping game 5990/6051: ID 414939
#     ✗ Skipping game 414939 - failed validation
#   Scraping game 5991/6051: ID 414940
#     ✗ Skipping game 414940 - failed validation
#   Scraping game 5992/6051: ID 414941
#     ✗ Skipping game 414941 - failed validation
#   Scraping game 5993/6051: ID 414942
#     ✗ Skipping game 414942 - failed validation
#   Scraping game 5994/6051: ID 414943
#     Rejecting game 414943 - null/empty field: mechanisms
#     ✗ Skipping game 414943 - failed validation
#   Scraping game 5995/6051: ID 414944
#     Rejecting game 414944 - null/empty field: category_ranks
#     ✗ Skipping game 414944 - failed validation
#   Scraping game 5996/6051: ID 414945
#     ✗ Skipping game 414945 - failed validation
#   Scraping game 5997/6051: ID 414946
#     Rejecting game 414946 - null/empty field: bgg_rank
#     ✗ Skipping game 414946 - failed validation
#   Scraping game 5998/6051: ID 414947
#     Rejecting game 414947 - null/empty field: bgg_rank
#     ✗ Skipping game 414947 - failed validation
#   Scraping game 5999/6051: ID 414948
#     Rejecting game 414948 - null/empty field: designers
#     ✗ Skipping game 414948 - failed validation
#   Scraping game 6000/6051: ID 414949
#     ✗ Skipping game 414949 - failed validation
#
# Processing batch 61: games 6001-6051
#   Scraping game 6001/6051: ID 414950
#     Rejecting game 414950 - null/empty field: designers
#     ✗ Skipping game 414950 - failed validation
#   Scraping game 6002/6051: ID 414951
#     ✗ Skipping game 414951 - failed validation
#   Scraping game 6003/6051: ID 414952
#     Rejecting game 414952 - null/empty field: bgg_rank
#     ✗ Skipping game 414952 - failed validation
#   Scraping game 6004/6051: ID 414953
#     Rejecting game 414953 - null/empty field: artists
#     ✗ Skipping game 414953 - failed validation
#   Scraping game 6005/6051: ID 414954
#     Rejecting game 414954 - null/empty field: bgg_rank
#     ✗ Skipping game 414954 - failed validation
#   Scraping game 6006/6051: ID 414955
#     Rejecting game 414955 - null/empty field: bgg_rank
#     ✗ Skipping game 414955 - failed validation
#   Scraping game 6007/6051: ID 414956
#     ✗ Skipping game 414956 - failed validation
#   Scraping game 6008/6051: ID 414957
#     ✗ Skipping game 414957 - failed validation
#   Scraping game 6009/6051: ID 414958
#     ✗ Skipping game 414958 - failed validation
#   Scraping game 6010/6051: ID 414959
#     Rejecting game 414959 - null/empty field: designers
#     ✗ Skipping game 414959 - failed validation
#   Scraping game 6011/6051: ID 414960
#     ✗ Skipping game 414960 - failed validation
#   Scraping game 6012/6051: ID 414961
#     ✗ Skipping game 414961 - failed validation
#   Scraping game 6013/6051: ID 414962
#     ✗ Skipping game 414962 - failed validation
#   Scraping game 6014/6051: ID 414963
#     ✗ Skipping game 414963 - failed validation
#   Scraping game 6015/6051: ID 414964
#     ✗ Skipping game 414964 - failed validation
#   Scraping game 6016/6051: ID 414965
#     ✗ Skipping game 414965 - failed validation
#   Scraping game 6017/6051: ID 414966
#     ✗ Skipping game 414966 - failed validation
#   Scraping game 6018/6051: ID 414967
#     ✗ Skipping game 414967 - failed validation
#   Scraping game 6019/6051: ID 414968
#     ✗ Skipping game 414968 - failed validation
#   Scraping game 6020/6051: ID 414969
#     Rejecting game 414969 - null/empty field: designers
#     ✗ Skipping game 414969 - failed validation
#   Scraping game 6021/6051: ID 414970
#     ✗ Skipping game 414970 - failed validation
#   Scraping game 6022/6051: ID 414971
#     ✗ Skipping game 414971 - failed validation
#   Scraping game 6023/6051: ID 414972
#     Rejecting game 414972 - null/empty field: artists
#     ✗ Skipping game 414972 - failed validation
#   Scraping game 6024/6051: ID 414973
#     ✗ Skipping game 414973 - failed validation
#   Scraping game 6025/6051: ID 414974
#     ✗ Skipping game 414974 - failed validation
#   Scraping game 6026/6051: ID 414975
#     ✗ Skipping game 414975 - failed validation
#   Scraping game 6027/6051: ID 414976
#     ✗ Skipping game 414976 - failed validation
#   Scraping game 6028/6051: ID 414977
#     Rejecting game 414977 - null/empty field: bgg_rank
#     ✗ Skipping game 414977 - failed validation
#   Scraping game 6029/6051: ID 414978
#     ✗ Skipping game 414978 - failed validation
#   Scraping game 6030/6051: ID 414979
#     ✗ Skipping game 414979 - failed validation
#   Scraping game 6031/6051: ID 414980
#     ✗ Skipping game 414980 - failed validation
#   Scraping game 6032/6051: ID 414981
#     ✗ Skipping game 414981 - failed validation
#   Scraping game 6033/6051: ID 414982
#     ✗ Skipping game 414982 - failed validation
#   Scraping game 6034/6051: ID 414983
#     ✗ Skipping game 414983 - failed validation
#   Scraping game 6035/6051: ID 414984
#     ✗ Skipping game 414984 - failed validation
#   Scraping game 6036/6051: ID 414985
#     ✗ Skipping game 414985 - failed validation
#   Scraping game 6037/6051: ID 414986
#     ✗ Skipping game 414986 - failed validation
#   Scraping game 6038/6051: ID 414987
#     ✗ Skipping game 414987 - failed validation
#   Scraping game 6039/6051: ID 414988
#     ✗ Skipping game 414988 - failed validation
#   Scraping game 6040/6051: ID 414989
#     ✗ Skipping game 414989 - failed validation
#   Scraping game 6041/6051: ID 414990
#     Rejecting game 414990 - null/empty field: artists
#     ✗ Skipping game 414990 - failed validation
#   Scraping game 6042/6051: ID 414991
#     ✗ Skipping game 414991 - failed validation
#   Scraping game 6043/6051: ID 414992
#     ✗ Skipping game 414992 - failed validation
#   Scraping game 6044/6051: ID 414993
#     Rejecting game 414993 - null/empty field: designers
#     ✗ Skipping game 414993 - failed validation
#   Scraping game 6045/6051: ID 414994
#     Rejecting game 414994 - null/empty field: artists
#     ✗ Skipping game 414994 - failed validation
#   Scraping game 6046/6051: ID 414995
#     Rejecting game 414995 - null/empty field: designers
#     ✗ Skipping game 414995 - failed validation
#   Scraping game 6047/6051: ID 414996
#     Rejecting game 414996 - null/empty field: category_ranks
#     ✗ Skipping game 414996 - failed validation
#   Scraping game 6048/6051: ID 414997
#     ✗ Skipping game 414997 - failed validation
#   Scraping game 6049/6051: ID 414998
#     ✗ Skipping game 414998 - failed validation
#   Scraping game 6050/6051: ID 414999
#     ✗ Skipping game 414999 - failed validation
#   Scraping game 6051/6051: ID 415000
#     ✗ Skipping game 415000 - failed validation
#
# Completed scraping. Total valid games: 16
# Cleaning dataframe - initial size: 16 games
# After critical field null check: 16 games (0 removed)
# After duplicate removal: 16 games (0 removed)
# After removing rows with >50.0% nulls: 16 games (0 removed)
#
# Final dataset null statistics:
# Final dataset saved to bgg_data/complete_bgg_dataset_20250723_022516.csv
#
# === SCRAPING COMPLETE ===
# Total games scraped: 16
# Columns: 23
# Date range: 2024 - 2025
# Average rating range: 6.64 - 8.35
#
# Sample data:
#              name  year_published  average_rating  bgg_rank
# 13      Harmonies            2024         8.02865        73
# 2        Wyrmspan            2024         7.99579       138
# 10   Bomb Busters            2024         8.03271       332
# 6        The Gang            2024         7.60245       646
# 7          Pixies            2024         7.09056      1583
# 1        Flatiron            2024         7.58098      2151
# 4           Looot            2024         7.06345      2285
# 8   Monkey Palace            2024         7.21786      2312
# 11      Botanicus            2024         7.42651      2389
# 15          Mesos            2024         7.01945      3211

# %%
import os
import pandas as pd

input_folder = r'C:\Users\suyil\OneDrive\Desktop\BIL476\project\bgg_complete'     # Replace with your actual folder path
output_file = 'complete_dataset.csv'      # Name of the resulting merged file

# === COMBINE CSV FILES ===
# Get all CSV file paths in the folder

csv_files = [f for f in os.listdir(input_folder) if f.endswith('.csv') and f.startswith('complete')]

# Read and concatenate all CSVs
df_list = []
for file in csv_files:
    file_path = os.path.join(input_folder, file)
    try:
        df = pd.read_csv(file_path)
        df_list.append(df)
        print(f"Loaded: {file}")
    except Exception as e:
        print(f"Error reading {file}: {e}")

# Concatenate all dataframes
if df_list:
    combined_df = pd.concat(df_list, ignore_index=True)
    combined_df.to_csv(os.path.join(input_folder, output_file), index=False)
    print(f"\n✅ All CSVs combined into {output_file}")
else:
    print("❌ No CSV files were successfully loaded.")
# Out:
# Loaded: complete_bgg_dataset_20250714_182120.csv
# Loaded: complete_bgg_dataset_20250714_202226.csv
# Loaded: complete_bgg_dataset_20250714_233432.csv
# Loaded: complete_bgg_dataset_20250715_055536.csv
# Loaded: complete_bgg_dataset_20250715_162016.csv
# Loaded: complete_bgg_dataset_20250716_170918.csv
# Loaded: complete_bgg_dataset_20250716_200224.csv
# Loaded: complete_bgg_dataset_20250716_223731.csv
# Loaded: complete_bgg_dataset_20250717_061747.csv
# Loaded: complete_bgg_dataset_20250717_133159.csv
# Loaded: complete_bgg_dataset_20250717_162545.csv
# Loaded: complete_bgg_dataset_20250719_005512.csv
# Loaded: complete_bgg_dataset_20250720_111435.csv
# Loaded: complete_bgg_dataset_20250721_123857.csv
# Loaded: complete_bgg_dataset_20250723_022516.csv
# Loaded: complete_bgg_dataset_20250723_071440.csv
#
# ✅ All CSVs combined into complete_dataset.csv
